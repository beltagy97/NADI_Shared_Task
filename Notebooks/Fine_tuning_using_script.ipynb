# %%
import torch

if torch.cuda.is_available():    
  
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla P4

# %%
cd 'drive/My Drive/NADI_release/transformers'
# Out:
# /content/drive/My Drive/NADI_release/transformers

# %%
# !pip uninstall -y tensorflow
# !pip install transformers
# Out:
# Uninstalling tensorflow-2.2.0rc4:
#   Successfully uninstalled tensorflow-2.2.0rc4
# ...
#      |████████████████████████████████| 645kB 45.6MB/s
# ...
#      |████████████████████████████████| 3.8MB 49.8MB/s
# ...
#      |████████████████████████████████| 1.0MB 53.8MB/s
# ...
#      |████████████████████████████████| 890kB 51.2MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=045a48f368c0555231a6c3a98fb281073c095f8561c74f04f0dd12a51e16b7f0
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
cmd =	"""
  python ./examples/run_language_modeling.py
  --train_data_file ./clean_data/1500000.csv
  --output_dir ./pretrained_bert
	--overwrite_output_dir
	--model_name_or_path=./pretrained_bert/pytorch_model.bin
	--mlm
	--config_name ./pretrained_bert
	--tokenizer_name ./pretrained_bert
	--do_train
	--line_by_line
	--learning_rate 2e-5
	--num_train_epochs 1
	--save_total_limit 2
	--save_steps 2000
	--per_gpu_train_batch_size 16
	--seed 42
""".replace("\n", " ")

# %%
# %%time
# !{cmd}
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  84% 26304/31251 [2:20:17<25:01,  3.29it/s]
# Iteration:  84% 26305/31251 [2:20:17<25:29,  3.23it/s]
# Iteration:  84% 26306/31251 [2:20:18<25:51,  3.19it/s]
# Iteration:  84% 26307/31251 [2:20:18<24:48,  3.32it/s]
# Iteration:  84% 26308/31251 [2:20:18<25:00,  3.29it/s]
# Iteration:  84% 26309/31251 [2:20:19<25:00,  3.29it/s]
# Iteration:  84% 26310/31251 [2:20:19<25:05,  3.28it/s]
# Iteration:  84% 26311/31251 [2:20:19<25:08,  3.28it/s]
# Iteration:  84% 26312/31251 [2:20:20<25:26,  3.24it/s]
# Iteration:  84% 26313/31251 [2:20:20<26:00,  3.17it/s]
# Iteration:  84% 26314/31251 [2:20:20<26:08,  3.15it/s]
# Iteration:  84% 26315/31251 [2:20:21<25:48,  3.19it/s]
# Iteration:  84% 26316/31251 [2:20:21<25:39,  3.21it/s]
# Iteration:  84% 26317/31251 [2:20:21<25:20,  3.24it/s]
# Iteration:  84% 26318/31251 [2:20:21<25:25,  3.23it/s]
# Iteration:  84% 26319/31251 [2:20:22<25:27,  3.23it/s]
# ...
